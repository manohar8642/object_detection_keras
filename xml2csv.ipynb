# %%
import numpy as np
import pandas as pd
import os
import xml.etree.ElementTree as ET
import csv

# %%
import os
path = 'C:/Users/manohar/Downloads/Dataset/test_dataset/'

# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET


def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


def main():
    for directory in ['train','test']:
        image_path = os.path.join(os.getcwd(), 'images/{}'.format(directory))
        xml_df = xml_to_csv(image_path)
        xml_df.to_csv('labels.csv'.format(directory), index=None)
        print('Successfully converted xml to csv.')

main()
# Out:
# Successfully converted xml to csv.
# Successfully converted xml to csv.

# %%
df = xml_to_csv(path)

# %%
df
# Out:
#                                 filename  width  height          class  xmin  \
# 0   VISUCI1_S1_20191206_153026_255_1.jpg   1024    1095           Tear    87
# 1   VISUCI1_S1_20191206_153026_255_1.jpg   1024    1095           Trim   192
# 2   VISUCI1_S1_20191206_153026_255_1.jpg   1024    1095    Mistracking   872
# 3   VISUCI1_S1_20191206_153026_255_1.jpg   1024    1095        Wrinkle   592
# 4   VISUCI1_S1_20191209_041519_565_3.jpg   1024    1095           Tear   666
# 5   VISUCI1_S1_20191209_041519_565_3.jpg   1024    1095           Trim   649
# 6   VISUCI1_S1_20191209_041519_565_3.jpg   1024    1095        Wrinkle   319
# 7   VISUCI1_S1_20191209_091230_868_1.jpg   1024    1095           Tear    94
# 8   VISUCI1_S1_20191209_091230_868_1.jpg   1024    1095           Trim   146
# 9   VISUCI1_S1_20191209_091230_868_1.jpg   1024    1095    Mistracking   836
# 10  VISUCI1_S1_20191209_091230_868_1.jpg   1024    1095           Trim   174
# 11  VISUCI1_S1_20200123_023549_722_1.jpg   1024    1095           Trim    73
# 12  VISUCI1_S1_20200123_023549_722_1.jpg   1024    1095    Mistracking   846
# 13  VISUCI1_S1_20200123_032651_385_1.jpg   1024    1095    Mistracking   164
# 14  VISUCI1_S1_20200123_032651_385_1.jpg   1024    1095           Tear   919
# 15  VISUCI1_S1_20200123_032651_385_1.jpg   1024    1095           Trim   163
# 16  VISUCI1_S1_20200123_032651_385_1.jpg   1024    1095    Mistracking   871
# 17  VISUCI1_S1_20200124_003340_854_1.jpg   1024    1095           Trim   377
# 18  VISUCI1_S1_20200124_003340_854_1.jpg   1024    1095    Mistracking   898
# 19  VISUCI1_S1_20200202_004717_619_3.jpg   1024    1095           Tear   696
# 20  VISUCI1_S1_20200202_004717_619_3.jpg   1024    1095        Wrinkle   722
# 21  VISUCI1_S1_20200204_134921_898_3.jpg   1024    1095           Tear   313
# 22  VISUCI1_S1_20200204_134921_898_3.jpg   1024    1095        Wrinkle   702
# 23  VISUCI1_S1_20200204_134921_898_3.jpg   1024    1095        Wrinkle   307
# 24  VISUCI1_S1_20200204_134921_898_3.jpg   1024    1095           Trim   317
# 25  VISUCI1_S1_20200204_175729_476_3.jpg   1024    1095  Contamination   622
# 26  VISUCI1_S1_20200204_184406_916_3.jpg   1024    1095  Contamination   575
# 27  VISUCI1_S1_20200204_203520_065_3.jpg   1024    1095  Contamination   586
# 28  VISUCI1_S1_20200204_203520_065_3.jpg   1024    1095  Contamination   586
# 29  VISUCI1_S1_20200205_005848_475_3.jpg   1024    1095           Fold   666
# 30  VISUCI1_S1_20200205_005848_475_3.jpg   1024    1095  Contamination   426
# 31  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095        Wrinkle   199
# 32  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095        Wrinkle   674
# 33  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095           Trim   381
# 34  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095           Tear   331
# 35  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095        Wrinkle   346
# 36  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095    Mistracking   198
# 37  VISUCI1_S1_20200205_225854_270_3.jpg   1024    1095    Mistracking   792
# 38  VISUCI1_S1_20200207_034847_345_3.jpg   1024    1095           Trim   134
# 39  VISUCI1_S1_20200207_034847_345_3.jpg   1024    1095           Tear   306
# 40  VISUCI1_S1_20200207_034847_345_3.jpg   1024    1095        Wrinkle   198
# 41  VISUCI1_S1_20200211_110135_236_1.jpg   1024    1095           Trim    13
# 42  VISUCI1_S1_20200212_103315_398_1.jpg   1024    1095           Trim   133
# 43  VISUCI1_S1_20200212_103315_398_1.jpg   1024    1095           Trim    83
# 44  VISUCI1_S1_20200212_103315_398_1.jpg   1024    1095           Tear   913
#
#     ymin  xmax  ymax
# 0    340   152   997
# 1     85  1006   393
# 2      1   904  1092
# 3    130   737   175
# 4    160   802   405
# 5    293   796   635
# 6    463   399  1090
# 7    567   169   945
# 8    535   794   677
# 9     70   869  1095
# 10    38   856    88
# 11   718   882   905
# 12   735   894  1092
# 13     1   198   677
# 14   278   959   923
# 15   677   853  1083
# 16     1   916   852
# 17     7  1014   477
# 18   430   926  1088
# 19    22   897   475
# 20   588   767  1092
# 21     1   442   287
# 22     1   761  1090
# 23   290   384   842
# 24   858   436  1092
# 25   483   638   502
# 26   515   602   828
# 27   737   609   788
# 28   132   612   463
# 29   102   719   277
# 30   470   467   918
# 31     1   324  1095
# 32     1   729  1095
# 33   308   632   453
# 34   422   379   557
# 35   568   394   970
# 36     1   234  1093
# 37     1   827  1093
# 38   542   918   767
# 39    10   389   115
# 40   178   242  1095
# 41   738   874   937
# 42   498   978   818
# 43    53   863   178
# 44   140   971   793

# %%
df.to_csv('test_dataset.csv')
